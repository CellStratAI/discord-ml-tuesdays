# %% [markdown]
# <img src="https://cellstrat2.s3.amazonaws.com/PlatformAssets/bluewhitelogo.svg" alt="drawing" width="200"/>
#
# # ML Tuesdays - Session 4
# ## Deep Learning Track
# ### CNN Transfer Learning Exercise
#
# Train a simple neural network in PyTorch to classify images of the CIFAR-10 dataset using CNNs.
#
# ### Guidelines
# 1. Use the `PyTorch 1.9` kernel in CellStrat Hub.
# 2. The notebook has been split into multiple steps. Complete the code wherever `# _____ TO-DO _____` is mentioned.
# 3. Here are a few references for you to look at to complete this exercise:
#     1. [Image Classification with PyTorch Webinar (Practical)](https://youtu.be/Dm1u2xwwSbQ)
#     2. [CNN Overview (Theory)](https://www.youtube.com/watch?v=IavC1j_A1F4)
# 4. Make use of the docstrings of the functions and classes using the `shift+tab` shortcut key.
# 5. Refer the internet for any extra help needed or just ping anyone from the team on discord.

# %%
from torch.utils.data import DataLoader
import pandas as pd
import torch
from torch import nn
import torchvision
from torchvision import transforms, models, datasets
import numpy as np
from PIL import Image
import os

# %% [markdown]
# ## Data

# %% [markdown]
# #### Download the Dataset

# %%
# Download the dataset
# !wget https://cellstrat-public.s3.amazonaws.com/workshop-files/data_cats_dogs.zip
# !unzip data_cats_dogs.zip
# !rm data_cats_dogs.zip
# Out:
# --2022-02-09 12:22:45--  https://cellstrat-public.s3.amazonaws.com/workshop-files/data_cats_dogs.zip
# Resolving cellstrat-public.s3.amazonaws.com (cellstrat-public.s3.amazonaws.com)... 52.216.25.28
# Connecting to cellstrat-public.s3.amazonaws.com (cellstrat-public.s3.amazonaws.com)|52.216.25.28|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 191813846 (183M) [application/zip]
# Saving to: ‘data_cats_dogs.zip’
#
# data_cats_dogs.zip  100%[===================>] 182.93M  91.2MB/s    in 2.0s
#
# 2022-02-09 12:22:47 (91.2 MB/s) - ‘data_cats_dogs.zip’ saved [191813846/191813846]
#
# Archive:  data_cats_dogs.zip
#    creating: data/
#    creating: data/train/
#    creating: data/train/cat/
#   inflating: data/train/cat/0.jpg
#   inflating: data/train/cat/1.jpg
#   inflating: data/train/cat/10.jpg
#   inflating: data/train/cat/100.jpg
#   inflating: data/train/cat/1000.jpg
#   inflating: data/train/cat/1001.jpg
#   inflating: data/train/cat/1002.jpg
#   inflating: data/train/cat/1003.jpg
#   inflating: data/train/cat/1004.jpg
#   inflating: data/train/cat/1005.jpg
#   inflating: data/train/cat/1006.jpg
#   inflating: data/train/cat/1007.jpg
#   inflating: data/train/cat/1008.jpg
#   inflating: data/train/cat/1009.jpg
#   inflating: data/train/cat/101.jpg
#   inflating: data/train/cat/1010.jpg
#   inflating: data/train/cat/1011.jpg
#   inflating: data/train/cat/1012.jpg
#   inflating: data/train/cat/1013.jpg
#   inflating: data/train/cat/1014.jpg
#   inflating: data/train/cat/1015.jpg
#   inflating: data/train/cat/1016.jpg
#   inflating: data/train/cat/1017.jpg
#   inflating: data/train/cat/1018.jpg
#   inflating: data/train/cat/1019.jpg
#   inflating: data/train/cat/102.jpg
#   inflating: data/train/cat/1020.jpg
#   inflating: data/train/cat/253.jpg
#   inflating: data/train/cat/254.jpg
#   inflating: data/train/cat/255.jpg
#   inflating: data/train/cat/256.jpg
#   inflating: data/train/cat/257.jpg
#   inflating: data/train/cat/258.jpg
#   inflating: data/train/cat/259.jpg
#   inflating: data/train/cat/26.jpg
#   inflating: data/train/cat/260.jpg
#   inflating: data/train/cat/261.jpg
#   inflating: data/train/cat/262.jpg
#   inflating: data/train/cat/263.jpg
#   inflating: data/train/cat/264.jpg
#   inflating: data/train/cat/265.jpg
#   inflating: data/train/cat/266.jpg
#   inflating: data/train/cat/267.jpg
#   inflating: data/train/cat/268.jpg
#   inflating: data/train/cat/269.jpg
#   inflating: data/train/cat/27.jpg
#   inflating: data/train/cat/270.jpg
#   inflating: data/train/cat/271.jpg
#   inflating: data/train/cat/272.jpg
#   inflating: data/train/cat/273.jpg
#   inflating: data/train/cat/274.jpg
#   inflating: data/train/cat/275.jpg
#   inflating: data/train/cat/276.jpg
#   inflating: data/train/cat/277.jpg
#   inflating: data/train/cat/278.jpg
#   inflating: data/train/cat/279.jpg
#   inflating: data/train/cat/28.jpg
#   inflating: data/train/cat/280.jpg
#   inflating: data/train/cat/281.jpg
#   inflating: data/train/cat/282.jpg
#   inflating: data/train/cat/283.jpg
#   inflating: data/train/cat/284.jpg
#   inflating: data/train/cat/285.jpg
#   inflating: data/train/cat/286.jpg
#   inflating: data/train/cat/287.jpg
#   inflating: data/train/cat/288.jpg
#   inflating: data/train/cat/289.jpg
#   inflating: data/train/cat/29.jpg
#   inflating: data/train/cat/290.jpg
#   inflating: data/train/cat/291.jpg
#   inflating: data/train/cat/292.jpg
# ...
#   inflating: data/validation/dog/2642.jpg
#   inflating: data/validation/dog/2643.jpg
#   inflating: data/validation/dog/2644.jpg
#   inflating: data/validation/dog/2645.jpg
#   inflating: data/validation/dog/2646.jpg
#   inflating: data/validation/dog/2647.jpg
#   inflating: data/validation/dog/2648.jpg
#   inflating: data/validation/dog/2649.jpg
#   inflating: data/validation/dog/2650.jpg
#   inflating: data/validation/dog/2651.jpg
#   inflating: data/validation/dog/2652.jpg
#   inflating: data/validation/dog/2653.jpg
#   inflating: data/validation/dog/2654.jpg
#   inflating: data/validation/dog/2655.jpg
#   inflating: data/validation/dog/2656.jpg
#   inflating: data/validation/dog/2657.jpg
#   inflating: data/validation/dog/2658.jpg
#   inflating: data/validation/dog/2659.jpg
#   inflating: data/validation/dog/2660.jpg
#   inflating: data/validation/dog/2661.jpg
#   inflating: data/validation/dog/2662.jpg
#   inflating: data/validation/dog/2663.jpg
#   inflating: data/validation/dog/2664.jpg
#   inflating: data/validation/dog/2665.jpg
#   inflating: data/validation/dog/2666.jpg
#   inflating: data/validation/dog/2667.jpg
#   inflating: data/validation/dog/2668.jpg
#   inflating: data/validation/dog/2669.jpg
#   inflating: data/validation/dog/2670.jpg
#   inflating: data/validation/dog/2671.jpg
#   inflating: data/validation/dog/2672.jpg
#   inflating: data/validation/dog/2673.jpg
#   inflating: data/validation/dog/2674.jpg
#   inflating: data/validation/dog/2675.jpg
#   inflating: data/validation/dog/2676.jpg
#   inflating: data/validation/dog/2677.jpg
#   inflating: data/validation/dog/2678.jpg
#   inflating: data/validation/dog/2679.jpg
#   inflating: data/validation/dog/2680.jpg
#   inflating: data/validation/dog/2681.jpg
#   inflating: data/validation/dog/2682.jpg
#   inflating: data/validation/dog/2683.jpg
#   inflating: data/validation/dog/2684.jpg
#   inflating: data/validation/dog/2685.jpg
#   inflating: data/validation/dog/2686.jpg
#   inflating: data/validation/dog/2687.jpg
#   inflating: data/validation/dog/2688.jpg
#   inflating: data/validation/dog/2689.jpg
#   inflating: data/validation/dog/2690.jpg
#   inflating: data/validation/dog/2691.jpg
#   inflating: data/validation/dog/2692.jpg
#   inflating: data/validation/dog/2693.jpg
#   inflating: data/validation/dog/2694.jpg
#   inflating: data/validation/dog/2695.jpg
#   inflating: data/validation/dog/2696.jpg
#   inflating: data/validation/dog/2697.jpg
#   inflating: data/validation/dog/2698.jpg
#   inflating: data/validation/dog/2699.jpg
#   inflating: data/validation/dog/2700.jpg
#   inflating: data/validation/dog/2701.jpg
#   inflating: data/validation/dog/2702.jpg
#   inflating: data/validation/dog/2703.jpg
#   inflating: data/validation/dog/2704.jpg
#   inflating: data/validation/dog/2705.jpg
#   inflating: data/validation/dog/2706.jpg
#   inflating: data/validation/dog/2707.jpg
#   inflating: data/validation/dog/2708.jpg
#   inflating: data/validation/dog/2709.jpg
#   inflating: data/validation/dog/2710.jpg
#   inflating: data/validation/dog/2711.jpg
#   inflating: data/validation/dog/2712.jpg
#   inflating: data/validation/dog/2713.jpg
#   inflating: data/validation/dog/2714.jpg
#   inflating: data/validation/dog/2715.jpg
#   inflating: data/validation/dog/2716.jpg
#   inflating: data/validation/dog/2717.jpg
#   inflating: data/validation/dog/2718.jpg
#   inflating: data/validation/dog/2719.jpg
#   inflating: data/validation/dog/2720.jpg
#   inflating: data/validation/dog/2721.jpg
#   inflating: data/validation/dog/2722.jpg
#   inflating: data/validation/dog/2723.jpg
#   inflating: data/validation/dog/2724.jpg
#   inflating: data/validation/dog/2725.jpg
#   inflating: data/validation/dog/2726.jpg
#   inflating: data/validation/dog/2727.jpg
#   inflating: data/validation/dog/2728.jpg
#   inflating: data/validation/dog/2729.jpg
#   inflating: data/validation/dog/2730.jpg
#   inflating: data/validation/dog/2731.jpg
#   inflating: data/validation/dog/2732.jpg
#   inflating: data/validation/dog/2733.jpg
#   inflating: data/validation/dog/2734.jpg
#   inflating: data/validation/dog/2735.jpg
#   inflating: data/validation/dog/2736.jpg
#   inflating: data/validation/dog/2737.jpg
#   inflating: data/validation/dog/2738.jpg
#   inflating: data/validation/dog/2739.jpg
#   inflating: data/validation/dog/2740.jpg
#   inflating: data/validation/dog/2741.jpg
#   inflating: data/validation/dog/2742.jpg
#   inflating: data/validation/dog/2743.jpg
#   inflating: data/validation/dog/2744.jpg
#   inflating: data/validation/dog/2745.jpg
#   inflating: data/validation/dog/2746.jpg
#   inflating: data/validation/dog/2747.jpg
#   inflating: data/validation/dog/2748.jpg
#   inflating: data/validation/dog/2749.jpg
#   inflating: data/validation/dog/2750.jpg
#   inflating: data/validation/dog/2751.jpg
#   inflating: data/validation/dog/2752.jpg
#   inflating: data/validation/dog/2753.jpg
#   inflating: data/validation/dog/2754.jpg
#   inflating: data/validation/dog/2755.jpg
#   inflating: data/validation/dog/2756.jpg
#   inflating: data/validation/dog/2757.jpg
#   inflating: data/validation/dog/2758.jpg
#   inflating: data/validation/dog/2759.jpg
#   inflating: data/validation/dog/2760.jpg
#   inflating: data/validation/dog/2761.jpg
#   inflating: data/validation/dog/2762.jpg
#   inflating: data/validation/dog/2763.jpg
#   inflating: data/validation/dog/2764.jpg
#   inflating: data/validation/dog/2765.jpg
#   inflating: data/validation/dog/2766.jpg
#   inflating: data/validation/dog/2767.jpg
#   inflating: data/validation/dog/2768.jpg
#   inflating: data/validation/dog/2769.jpg
#   inflating: data/validation/dog/2770.jpg
#   inflating: data/validation/dog/2771.jpg
#   inflating: data/validation/dog/2772.jpg
#   inflating: data/validation/dog/2773.jpg
#   inflating: data/validation/dog/2774.jpg
#   inflating: data/validation/dog/2775.jpg
#   inflating: data/validation/dog/2776.jpg
#   inflating: data/validation/dog/2777.jpg
#   inflating: data/validation/dog/2778.jpg
#   inflating: data/validation/dog/2779.jpg
#   inflating: data/validation/dog/2780.jpg
#   inflating: data/validation/dog/2781.jpg
#   inflating: data/validation/dog/2782.jpg
#   inflating: data/validation/dog/2783.jpg
#   inflating: data/validation/dog/2784.jpg
#   inflating: data/validation/dog/2785.jpg
#   inflating: data/validation/dog/2786.jpg
#   inflating: data/validation/dog/2787.jpg
#   inflating: data/validation/dog/2788.jpg
#   inflating: data/validation/dog/2789.jpg
#   inflating: data/validation/dog/2790.jpg
#   inflating: data/validation/dog/2791.jpg
#   inflating: data/validation/dog/2792.jpg
#   inflating: data/validation/dog/2793.jpg
#   inflating: data/validation/dog/2794.jpg
#   inflating: data/validation/dog/2795.jpg
#   inflating: data/validation/dog/2796.jpg
#   inflating: data/validation/dog/2797.jpg
#   inflating: data/validation/dog/2798.jpg
#   inflating: data/validation/dog/2799.jpg
#   inflating: data/validation/dog/2800.jpg
#   inflating: data/validation/dog/2801.jpg
#   inflating: data/validation/dog/2802.jpg
#   inflating: data/validation/dog/2803.jpg
#   inflating: data/validation/dog/2804.jpg
#   inflating: data/validation/dog/2805.jpg
#   inflating: data/validation/dog/2806.jpg
#   inflating: data/validation/dog/2807.jpg
#   inflating: data/validation/dog/2808.jpg
#   inflating: data/validation/dog/2809.jpg
#   inflating: data/validation/dog/2810.jpg
#   inflating: data/validation/dog/2811.jpg
#   inflating: data/validation/dog/2812.jpg
#   inflating: data/validation/dog/2813.jpg
#   inflating: data/validation/dog/2814.jpg
#   inflating: data/validation/dog/2815.jpg
#   inflating: data/validation/dog/2816.jpg
#   inflating: data/validation/dog/2817.jpg
#   inflating: data/validation/dog/2818.jpg
#   inflating: data/validation/dog/2819.jpg
#   inflating: data/validation/dog/2820.jpg
#   inflating: data/validation/dog/2821.jpg
#   inflating: data/validation/dog/2822.jpg
#   inflating: data/validation/dog/2823.jpg
#   inflating: data/validation/dog/2824.jpg
#   inflating: data/validation/dog/2825.jpg
#   inflating: data/validation/dog/2826.jpg
#   inflating: data/validation/dog/2827.jpg
#   inflating: data/validation/dog/2828.jpg
#   inflating: data/validation/dog/2829.jpg
#   inflating: data/validation/dog/2830.jpg
#   inflating: data/validation/dog/2831.jpg
#   inflating: data/validation/dog/2832.jpg
#   inflating: data/validation/dog/2833.jpg
#   inflating: data/validation/dog/2834.jpg
#   inflating: data/validation/dog/2835.jpg
#   inflating: data/validation/dog/2836.jpg
#   inflating: data/validation/dog/2837.jpg
#   inflating: data/validation/dog/2838.jpg
#   inflating: data/validation/dog/2839.jpg
#   inflating: data/validation/dog/2840.jpg
#   inflating: data/validation/dog/2841.jpg
#   inflating: data/validation/dog/2842.jpg
#   inflating: data/validation/dog/2843.jpg
#   inflating: data/validation/dog/2844.jpg
#   inflating: data/validation/dog/2845.jpg
#   inflating: data/validation/dog/2846.jpg
#   inflating: data/validation/dog/2847.jpg
#   inflating: data/validation/dog/2848.jpg
#   inflating: data/validation/dog/2849.jpg
#   inflating: data/validation/dog/2850.jpg
#   inflating: data/validation/dog/2851.jpg
#   inflating: data/validation/dog/2852.jpg
#   inflating: data/validation/dog/2853.jpg
#   inflating: data/validation/dog/2854.jpg
#   inflating: data/validation/dog/2855.jpg
#   inflating: data/validation/dog/2856.jpg
#   inflating: data/validation/dog/2857.jpg
#   inflating: data/validation/dog/2858.jpg
#   inflating: data/validation/dog/2859.jpg
#   inflating: data/validation/dog/2860.jpg
#   inflating: data/validation/dog/2861.jpg
#   inflating: data/validation/dog/2862.jpg
#   inflating: data/validation/dog/2863.jpg
#   inflating: data/validation/dog/2864.jpg
#   inflating: data/validation/dog/2865.jpg
#   inflating: data/validation/dog/2866.jpg
#   inflating: data/validation/dog/2867.jpg
#   inflating: data/validation/dog/2868.jpg
#   inflating: data/validation/dog/2869.jpg
#   inflating: data/validation/dog/2870.jpg
#   inflating: data/validation/dog/2871.jpg
#   inflating: data/validation/dog/2872.jpg
#   inflating: data/validation/dog/2873.jpg
#   inflating: data/validation/dog/2874.jpg
#   inflating: data/validation/dog/2875.jpg
#   inflating: data/validation/dog/2876.jpg
#   inflating: data/validation/dog/2877.jpg
#   inflating: data/validation/dog/2878.jpg
#   inflating: data/validation/dog/2879.jpg
#   inflating: data/validation/dog/2880.jpg
#   inflating: data/validation/dog/2881.jpg
#   inflating: data/validation/dog/2882.jpg
#   inflating: data/validation/dog/2883.jpg
#   inflating: data/validation/dog/2884.jpg
#   inflating: data/validation/dog/2885.jpg
#   inflating: data/validation/dog/2886.jpg
#   inflating: data/validation/dog/2887.jpg
#   inflating: data/validation/dog/2888.jpg
#   inflating: data/validation/dog/2889.jpg
#   inflating: data/validation/dog/2890.jpg
#   inflating: data/validation/dog/2891.jpg
#   inflating: data/validation/dog/2892.jpg
#   inflating: data/validation/dog/2893.jpg
#   inflating: data/validation/dog/2894.jpg
#   inflating: data/validation/dog/2895.jpg
#   inflating: data/validation/dog/2896.jpg
#   inflating: data/validation/dog/2897.jpg
#   inflating: data/validation/dog/2898.jpg
#   inflating: data/validation/dog/2899.jpg
#   inflating: data/validation/dog/2900.jpg
#   inflating: data/validation/dog/2901.jpg
#   inflating: data/validation/dog/2902.jpg
#   inflating: data/validation/dog/2903.jpg
#   inflating: data/validation/dog/2904.jpg
#   inflating: data/validation/dog/2905.jpg
#   inflating: data/validation/dog/2906.jpg
#   inflating: data/validation/dog/2907.jpg
#   inflating: data/validation/dog/2908.jpg
#   inflating: data/validation/dog/2909.jpg
#   inflating: data/validation/dog/2910.jpg
#   inflating: data/validation/dog/2911.jpg
#   inflating: data/validation/dog/2912.jpg
#   inflating: data/validation/dog/2913.jpg
#   inflating: data/validation/dog/2914.jpg
#   inflating: data/validation/dog/2915.jpg
#   inflating: data/validation/dog/2916.jpg
#   inflating: data/validation/dog/2917.jpg
#   inflating: data/validation/dog/2918.jpg
#   inflating: data/validation/dog/2919.jpg
#   inflating: data/validation/dog/2920.jpg
#   inflating: data/validation/dog/2921.jpg
#   inflating: data/validation/dog/2922.jpg
#   inflating: data/validation/dog/2923.jpg
#   inflating: data/validation/dog/2924.jpg
#   inflating: data/validation/dog/2925.jpg
#   inflating: data/validation/dog/2926.jpg
#   inflating: data/validation/dog/2927.jpg
#   inflating: data/validation/dog/2928.jpg
#   inflating: data/validation/dog/2929.jpg
#   inflating: data/validation/dog/2930.jpg
#   inflating: data/validation/dog/2931.jpg
#   inflating: data/validation/dog/2932.jpg
#   inflating: data/validation/dog/2933.jpg
#   inflating: data/validation/dog/2934.jpg
#   inflating: data/validation/dog/2935.jpg
#   inflating: data/validation/dog/2936.jpg
#   inflating: data/validation/dog/2937.jpg
#   inflating: data/validation/dog/2938.jpg
#   inflating: data/validation/dog/2939.jpg
#   inflating: data/validation/dog/2940.jpg
#   inflating: data/validation/dog/2941.jpg
#   inflating: data/validation/dog/2942.jpg
#   inflating: data/validation/dog/2943.jpg
#   inflating: data/validation/dog/2944.jpg
#   inflating: data/validation/dog/2945.jpg
#   inflating: data/validation/dog/2946.jpg
#   inflating: data/validation/dog/2947.jpg
#   inflating: data/validation/dog/2948.jpg
#   inflating: data/validation/dog/2949.jpg
#   inflating: data/validation/dog/2950.jpg
#   inflating: data/validation/dog/2951.jpg
#   inflating: data/validation/dog/2952.jpg
#   inflating: data/validation/dog/2953.jpg
#   inflating: data/validation/dog/2954.jpg
#   inflating: data/validation/dog/2955.jpg
#   inflating: data/validation/dog/2956.jpg
#   inflating: data/validation/dog/2957.jpg
#   inflating: data/validation/dog/2958.jpg
#   inflating: data/validation/dog/2959.jpg
#   inflating: data/validation/dog/2960.jpg
#   inflating: data/validation/dog/2961.jpg
#   inflating: data/validation/dog/2962.jpg
#   inflating: data/validation/dog/2963.jpg
#   inflating: data/validation/dog/2964.jpg
#   inflating: data/validation/dog/2965.jpg
#   inflating: data/validation/dog/2966.jpg
#   inflating: data/validation/dog/2967.jpg
#   inflating: data/validation/dog/2968.jpg
#   inflating: data/validation/dog/2969.jpg
#   inflating: data/validation/dog/2970.jpg
#   inflating: data/validation/dog/2971.jpg
#   inflating: data/validation/dog/2972.jpg
#   inflating: data/validation/dog/2973.jpg
#   inflating: data/validation/dog/2974.jpg
#   inflating: data/validation/dog/2975.jpg
#   inflating: data/validation/dog/2976.jpg
#   inflating: data/validation/dog/2977.jpg
#   inflating: data/validation/dog/2978.jpg
#   inflating: data/validation/dog/2979.jpg
#   inflating: data/validation/dog/2980.jpg
#   inflating: data/validation/dog/2981.jpg
#   inflating: data/validation/dog/2982.jpg
#   inflating: data/validation/dog/2983.jpg
#   inflating: data/validation/dog/2984.jpg
#   inflating: data/validation/dog/2985.jpg
#   inflating: data/validation/dog/2986.jpg
#   inflating: data/validation/dog/2987.jpg
#   inflating: data/validation/dog/2988.jpg
#   inflating: data/validation/dog/2989.jpg
#   inflating: data/validation/dog/2990.jpg
#   inflating: data/validation/dog/2991.jpg
#   inflating: data/validation/dog/2992.jpg
#   inflating: data/validation/dog/2993.jpg
#   inflating: data/validation/dog/2994.jpg
#   inflating: data/validation/dog/2995.jpg
#   inflating: data/validation/dog/2996.jpg
#   inflating: data/validation/dog/2997.jpg
#   inflating: data/validation/dog/2998.jpg
#   inflating: data/validation/dog/2999.jpg
#   inflating: data/validation/dog/3000.jpg
#   inflating: data/validation/dog/3001.jpg
#   inflating: data/validation/dog/3002.jpg
#   inflating: data/validation/dog/3003.jpg
#   inflating: data/validation/dog/3004.jpg

# %% [markdown]
# You may explore the `data` folder and inspect the dataset before proceeding further.
#
# * There are 2000 Training Images, 1000 for each of the two classes
# * There are 1000 Validation Images, 500 for each of the two classes

# %% [markdown]
# ### Loading the Dataset
# Your Directory Structure of cats and dogs should be like this.
# ```
# data
#     train
#         |__ cat
#                 |__ cat.1.jpg
#                 |__ cat.2.jpg
#         |__ dog
#                 |__ dog.1.jpg
#                 |__ dog.2.jpg
#     validation
#         |__ cat
#                 |__ cat.1.jpg
#                 |__ cat.2.jpg
#         |__ dog
#                 |__ dog.1.jpg
#                 |__ dog.2.jpg
# ```

# %% [markdown]
# In the next few cells you need apply a chain of transformations and load the ataset and create the DataLoaders.
#
# TO-DO:
# 1. Use transforms.Compose to add image augmentations but the last two should be Resizing to 256x256 and converting to Tensor.
#
# For example:
# ```python
# augmentations = transforms.Compose([transforms.RandomHorizontalFlip(),
#                                     #...add more such augmentations..,
#                                     transforms.Resize((256,256)),
#                                     transforms.ToTensor()])
# ```
# 2. Create the DataLoader

# %%
# _____ TO-DO _____
# Create the Chained Transformations
augmentations = transforms.Compose([transforms.RandomHorizontalFlip(), 
                                    transforms.RandomVerticalFlip(), 
                                    transforms.RandomRotation(30), 
                                    transforms.Resize((256,256)),
                                    transforms.ToTensor()])

# %%
# Loading the dataset from the folder and apply the transformations
train_data = datasets.ImageFolder('data/train/', transform=augmentations)
val_data = datasets.ImageFolder('data/validation/', transform=augmentations)

# %%
# _____ TO-DO _____
# Create a dataloader for the dataset
train_loader = DataLoader(train_data, batch_size=16, shuffle=True)
val_loader = DataLoader(val_data, batch_size=16, shuffle=True)

# %% [markdown]
# ## Model
# Use transfer learning to train a binary image classifier to recognize cats and dogs. Remember that its a binary classification problem so the final output features should be equal to 1.
#
# Steps / TO-DO:
# 1. Load a pretrained model from torchvision and make sure to set `pretrained=True` while loading the model. You can check the [available models here](https://pytorch.org/docs/stable/torchvision/models.html#classification)
# 2. Freeze the Model Params
# 3. Override the final classification block of layers with your own `nn.Sequential` layers for classification

# %%
# _____ TO-DO _____
# Load the pretrained model
model = models.resnet34(pretrained=True)
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
# Freeze the model
for param in model.parameters():
    # _____ TO-DO _____
    # set the requires_grad property to False for param
    param.requires_grad = False

# %%
# _____ TO-DO _____
# Override the final block with Sequential layers and the final output as 1 with a sigmoid activation at the end
model.fc = nn.Sequential(nn.Linear(512, 1024),
                         nn.ReLU(),
                         nn.Linear(1024, 512),
                         nn.ReLU(),
                         nn.Linear(512, 1),
                         nn.Sigmoid())

# %%
# view the updated model
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1024, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=1, bias=True)
#     (5): Sigmoid()
#   )
# )

# %% [markdown]
# ## Training

# %% [markdown]
# ### Define the Loss and Optimizer

# %%
# Create the Loss
criterion = nn.BCELoss()
# Create the optimizer by passing only the last block of layers' parameters for optimization
optimizer = torch.optim.Adam(model.fc.parameters(), lr=0.0001)

# %% [markdown]
# ### Define the Training Loop
#
# As we have very less data, we would instead write a training loop without a validation step. We will use the test_data for separately evaluating the model.
#
# Complete the training function below.
#
# TO-DO:
# 1. Complete the Training Loop
#     1. Pass the input through the model to get the output
#     2. Calculate Loss. Make sure
#         * The input of criterion is squeezed
#         * The target of criterion is of type float
#     3. Backpropagate
#     4. Optimize
# 2. Complete the Validation Loop
#     1. Pass the input through the model to get the output
#     2. Calculate Loss. Make sure
#         * The input of criterion is squeezed
#         * The target of criterion is of type float
#     3. Backpropagate
#     4. Optimize

# %%
def train(model, 
          train_loader,
          val_loader,
          criterion,
          optimizer, 
          device='cpu', 
          nb_epochs=2,
          print_every=100):
    
    # push to model to the device (CUDA or CPU)
    model.to(device)
    
    # start epoch
    for current_epoch in range(nb_epochs):
        
        print('Started Epoch {}...\n'.format(current_epoch+1))
        
        # TRAIN
        
        # set the model to train
        model.train()
        
        # loop over the batches of the train loader
        for i, (images, labels) in enumerate(train_loader):
            # move the data to selected device
            images = images.to(device)
            labels = labels.to(device)
            
            # set the optimizer to zero gradients
            optimizer.zero_grad()
            
            # _____ TO-DO _____
            # pass the inputs through the model
            outputs = model(images)
            
            # _____ TO-DO _____
            # calculate loss
            loss = criterion(outputs.squeeze(), labels.float())
            
            # _____ TO-DO _____
            # backpropagate
            loss.backward()
            
            # _____ TO-DO _____
            # optimize
            optimizer.step()
            
            # print the losses
            if i % print_every == 0:
                print('Epoch {} Step {}/{} Loss {}'.format(current_epoch+1, i, len(train_loader), loss.item()))
                
        # VALIDATION
        
        # set the model to evaluation
        model.eval()
        
        # we don't have to calculate gradients during validation
        with torch.no_grad():
            
            val_losses = []
            
            for i, (images, labels) in enumerate(val_loader):
                # move the data to selected device
                images = images.to(device)
                labels = labels.to(device)
                
                # _____ TO-DO _____
                # pass the inputs through the model
                outputs = model(images)
                
                # _____ TO-DO _____
                # calculate loss
                loss = criterion(outputs.squeeze(), labels.float())
                
                # append the losses
                val_losses.append(loss.item())

            print('\nValidation Loss {}'.format(sum(val_losses)/len(val_losses)))
            
        print('\nEnd of Epoch {}\n\n'.format(current_epoch+1))

# %%
# Get cpu or gpu device automatically for training.
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
# %%time
# Train the Model
train(model, train_loader, val_loader, criterion, optimizer, device=device, nb_epochs=3, print_every=100)
# Out:
# Started Epoch 1...
# /home/ubuntu/anaconda3/envs/pytorch/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /opt/conda/conda-bld/pytorch_1623448216815/work/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Epoch 1 Step 0 Loss 0.6946954131126404
# Epoch 1 Step 100 Loss 0.14400659501552582
# Epoch 1 Step 200 Loss 0.19618140161037445
#
# Validation Loss 0.19954779464006425
#
# End of Epoch 1
#
#
# Started Epoch 2...
#
# Epoch 2 Step 0 Loss 0.4967731833457947
# Epoch 2 Step 100 Loss 0.4422396421432495
# Epoch 2 Step 200 Loss 0.5133571028709412
#
# Validation Loss 0.16037369284033776
#
# End of Epoch 2
#
#
# Started Epoch 3...
#
# Epoch 3 Step 0 Loss 0.3112757205963135
# Epoch 3 Step 100 Loss 0.2796485722064972
# Epoch 3 Step 200 Loss 0.19770866632461548
#
# Validation Loss 0.15519433736801147
#
# End of Epoch 3
#
#
# CPU times: user 33min 10s, sys: 2min 29s, total: 35min 40s
# Wall time: 35min 45s

# %% [markdown]
# ### Save the model

# %%
torch.save(model.state_dict(), 'model.pt')

# %% [markdown]
# ## Inference
# Create a `predict()` function to take an image path as input and return Dogs or Cats as the output
#
# Steps / TO-DO:
# 1. Read the Image using PIL
# 2. Transform the image into a tensor using `transforms.ToTensor()`
# 3. Forward pass the image_tensor through the model
# 4. Return Cats or Dogs based if output is lesser or greater than 0.5 respectively

# %%
model.load_state_dict(torch.load('model.pt'))
# Out:
# <All keys matched successfully>

# %%
def predict(image_path, model, device='cpu'):
    
    # _____ TO-DO _____
    # Read the image with PIL
    image = Image.open(image_path)
    
    # _____ TO-DO _____
    # Create a transformation called tensorify to convert an image to a tensor
    tensorify = transforms.ToTensor()
    image_tensor = tensorify(image)
    
    # Unsqeeze image_tensor to reshape to [1, n_channels, height, width]
    image_tensor = image_tensor.unsqueeze(0)
    
    # set the model to evaluation mode and push to device
    model.eval()
    model.to(device)
    
    with torch.no_grad():
        # mount input to the appropriate device
        x = image_tensor.to(device)
        
        # _____ TO-DO _____
        # Make prediction
        output = model(x)
        print('Result:',output.item())
        
        # _____ TO-DO _____
        # Create a condition that if output.item() is less than 0.5 return 'Cat'
        # else return 'Dog'
        if output.item() < 0.5:
            return 'Cat'
        else:
            return 'Dog'

# %%
# test the function on some images
predict('cat.jpg', model)
# Out:
# Result: 0.0006576029118150473
# 'Cat'
